# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Pushkar-Varshney-K/CipherSchools-Hybrid-DS-ML/blob/Final-Project/Data_Collection_and_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Collection and Cleaning:

# %%
# from google.colab import drive
import pandas as pd
import numpy as np

# Mount Google Drive
# drive.mount('/content/drive')
# drive_filePath = "/content/drive/MyDrive/CSV/Mall_Customers.csv"

#importing dataSet (Mall_Customers.csv)
df = pd.read_csv('Mall_Customers.csv')

df.head(10) #starting 5 rows of file
# Out:
#    CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.0                15.0                    39.0
# 1           2    Male  21.0                15.0                    81.0
# 2           3  Female   NaN                16.0                     6.0
# 3           4  Female  23.0                16.0                    77.0
# 4           5  Female  31.0                17.0                    40.0
# 5           6  Female   NaN                17.0                    76.0
# 6           7  Female  35.0                18.0                     6.0
# 7           8  Female  23.0                 NaN                    94.0
# 8           9    Male  64.0                19.0                     3.0
# 9          10  Female  30.0                19.0                    72.0

# %% [markdown]
# # Data Cleaning:

# %%
# Rename the wrong columns name:

df.columns = ['Customer_Id', 'Gender', 'Age', 'Annual_Income', 'Spending_Score']
df.head(10)
# Out:
#    Customer_Id  Gender   Age  Annual_Income  Spending_Score
# 0            1    Male  19.0           15.0            39.0
# 1            2    Male  21.0           15.0            81.0
# 2            3  Female   NaN           16.0             6.0
# 3            4  Female  23.0           16.0            77.0
# 4            5  Female  31.0           17.0            40.0
# 5            6  Female   NaN           17.0            76.0
# 6            7  Female  35.0           18.0             6.0
# 7            8  Female  23.0            NaN            94.0
# 8            9    Male  64.0           19.0             3.0
# 9           10  Female  30.0           19.0            72.0

# %%
# total missing values according to column

count = df.isnull().sum()
print("Total missing values in the file: \n\n",count)
# Out:
# Total missing values in the file:
#
#  Customer_Id       0
# Gender            0
# Age               5
# Annual_Income     4
# Spending_Score    5
# dtype: int64

# %%
# Handling missing values

avg_age = df['Age'].mean()
df['Age'].fillna(avg_age, inplace=True)
# CONVERT the mean_age into "INTEGER" Because age can not be float...
df['Age'] = df['Age'].astype(int)

avg_Spending = df['Spending_Score'].mean()
df['Spending_Score'].fillna(avg_Spending, inplace=True)

max_gender = df['Gender'].mode()[0] # "[0]" for choosing the first "MOD" if more than 1 mod is present
df['Gender'].fillna(max_gender, inplace=True)

avg_income = df['Annual_Income'].mean()
df['Annual_Income'].fillna(avg_income, inplace=True)

df.head(10)
# Out:
#    Customer_Id  Gender  Age  Annual_Income  Spending_Score
# 0            1    Male   19      15.000000            39.0
# 1            2    Male   21      15.000000            81.0
# 2            3  Female   39      16.000000             6.0
# 3            4  Female   23      16.000000            77.0
# 4            5  Female   31      17.000000            40.0
# 5            6  Female   39      17.000000            76.0
# 6            7  Female   35      18.000000             6.0
# 7            8  Female   23      60.704082            94.0
# 8            9    Male   64      19.000000             3.0
# 9           10  Female   30      19.000000            72.0

# %%
df.dropna(inplace=True)
df.head(10)
# Out:
#    Customer_Id  Gender  Age  Annual_Income  Spending_Score
# 0            1    Male   19      15.000000            39.0
# 1            2    Male   21      15.000000            81.0
# 2            3  Female   39      16.000000             6.0
# 3            4  Female   23      16.000000            77.0
# 4            5  Female   31      17.000000            40.0
# 5            6  Female   39      17.000000            76.0
# 6            7  Female   35      18.000000             6.0
# 7            8  Female   23      60.704082            94.0
# 8            9    Male   64      19.000000             3.0
# 9           10  Female   30      19.000000            72.0

# %%
# Data transformation: Encoding categorial variables:->

df['Gender'] = df['Gender'].map({'Male' : 0, 'Female' : 1})

# %%
#Now Checking file contain any empty/missing value:

print(df.isnull().sum())
# Take a look on Data
df.head(10)
# Out:
# Customer_Id       0
# Gender            0
# Age               0
# Annual_Income     0
# Spending_Score    0
# dtype: int64
#    Customer_Id  Gender  Age  Annual_Income  Spending_Score
# 0            1       0   19      15.000000            39.0
# 1            2       0   21      15.000000            81.0
# 2            3       1   39      16.000000             6.0
# 3            4       1   23      16.000000            77.0
# 4            5       1   31      17.000000            40.0
# 5            6       1   39      17.000000            76.0
# 6            7       1   35      18.000000             6.0
# 7            8       1   23      60.704082            94.0
# 8            9       0   64      19.000000             3.0
# 9           10       1   30      19.000000            72.0

# %% [markdown]
# # Download the clean file

# %%
from google.colab import files

df.to_csv('cleaned_mall_customers.csv', index=False) #to remove the indexes which written by colab with file name "cleaned_mall_customers.csv"
# df.to_csv(drive_filePath, index=False) #store the cleaned file by converting into CSV file in the drive

files.download('cleaned_mall_customers.csv') # store in your laptop/Comp.
